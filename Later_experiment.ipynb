# %%
import json
import pandas as pd
from pandas import json_normalize

# %%
with open('data_1.json') as data_1:
    read_content_1 = json.load(data_1)
with open('data_2.json') as data_2:
    read_content_2 = json.load(data_2)
with open('data_3.json') as data_3:
    read_content_3 = json.load(data_3)

# %%
read_content_1
# Out:
# [{'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013,
#   'payload': {'data': [{'antenna': 'Antenna2',
#      'datetime': '2022-07-06 18:53:33.0827',
#      'readername': 'Modjoul Test 2',
#      'epc': 'MODJ00000139',
#      'deviceid': 'A5:8D:ZC:90:95:9Z',
#      'user': 'null',
#      'tagevent': 'Tag Visible',
#      'peakrssi': -56},
#     {'antenna': 'Antenna1',
#      'datetime': '2022-07-06 18:53:37.0157',
#      'readername': 'Modjoul Test 2',
#      'epc': 'MODJ00000139',
#      'deviceid': 'A5:8D:ZC:90:95:9Z',
#      'user': 'null',
#      'tagevent': 'Tag Visible',
#      'peakrssi': -55},
#     {'antenna': 'Antenna2',
#      'datetime': '2022-07-06 18:53:40.0427',
#      'readername': 'Modjoul Test 2',
#      'epc': 'MODJ00000139',
#      'deviceid': 'A5:8D:ZC:90:95:9Z',
#      'user': 'null',
#      'tagevent': 'Tag Visible',
#      'peakrssi': -58},
#     {'antenna': 'Antenna1',
#      'datetime': '2022-07-06 18:53:37.0216',
# ...

# %%
read_content_1[0]
# Out:
# {'tenantName': 'GREENVILLE',
#  'eventType': 'EXIT',
#  'eventTimeEpoch': 1657152013,
#  'payload': {'data': [{'antenna': 'Antenna2',
#     'datetime': '2022-07-06 18:53:33.0827',
#     'readername': 'Modjoul Test 2',
#     'epc': 'MODJ00000139',
#     'deviceid': 'A5:8D:ZC:90:95:9Z',
#     'user': 'null',
#     'tagevent': 'Tag Visible',
#     'peakrssi': -56},
#    {'antenna': 'Antenna1',
#     'datetime': '2022-07-06 18:53:37.0157',
#     'readername': 'Modjoul Test 2',
#     'epc': 'MODJ00000139',
#     'deviceid': 'A5:8D:ZC:90:95:9Z',
#     'user': 'null',
#     'tagevent': 'Tag Visible',
#     'peakrssi': -55},
#    {'antenna': 'Antenna2',
#     'datetime': '2022-07-06 18:53:40.0427',
#     'readername': 'Modjoul Test 2',
#     'epc': 'MODJ00000139',
#     'deviceid': 'A5:8D:ZC:90:95:9Z',
#     'user': 'null',
#     'tagevent': 'Tag Visible',
#     'peakrssi': -58},
#    {'antenna': 'Antenna1',
#     'datetime': '2022-07-06 18:53:37.0216',
#     'readername': 'Modjoul Test 2',
# ...

# %%
inner_1 =read_content_1[0].pop('payload')
instances_2 =read_content_2[0].pop('payload')
instances_3 =read_content_3[0].pop('payload')

# %%
instances_1 = inner_1.pop('data')

# %%
instances_1
# Out:
# [{'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:33.0827',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -56},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:37.0157',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -55},
#  {'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:40.0427',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -58},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:37.0216',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000138',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -59},
# ...

# %%
inner_1
# Out:
# {'accountuuid': '12345678911223344',
#  'version': '1.0',
#  'deviceid': 'A5:8D:ZC:90:95:9Z'}

# %%
read_content_1[0]
# Out:
# {'tenantName': 'GREENVILLE', 'eventType': 'EXIT', 'eventTimeEpoch': 1657152013}

# %%
inner_1.update(read_content_1[0])

# %%
inner_1
# Out:
# {'accountuuid': '12345678911223344',
#  'version': '1.0',
#  'deviceid': 'A5:8D:ZC:90:95:9Z',
#  'tenantName': 'GREENVILLE',
#  'eventType': 'EXIT',
#  'eventTimeEpoch': 1657152013}

# %%
instances_1
# Out:
# [{'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:33.0827',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -56},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:37.0157',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -55},
#  {'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:40.0427',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -58},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:37.0216',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000138',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -59},
# ...

# %%
instances_2
# Out:
# {'data': [{'antenna': 'Antenna2',
#    'datetime': '2022-07-06 18:53:33.0827',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000139',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
#    'peakrssi': -56},
#   {'antenna': 'Antenna1',
#    'datetime': '2022-07-06 18:53:37.0157',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000139',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
#    'peakrssi': -55},
#   {'antenna': 'Antenna2',
#    'datetime': '2022-07-06 18:53:40.0427',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000139',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
#    'peakrssi': -58},
#   {'antenna': 'Antenna1',
#    'datetime': '2022-07-06 18:53:37.0216',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000138',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
# ...

# %%
instances_3
# Out:
# {'data': [{'antenna': 'Antenna2',
#    'datetime': '2022-07-06 18:53:33.0827',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000139',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
#    'peakrssi': -56},
#   {'antenna': 'Antenna1',
#    'datetime': '2022-07-06 18:53:37.0157',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000139',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
#    'peakrssi': -55},
#   {'antenna': 'Antenna2',
#    'datetime': '2022-07-06 18:53:40.0427',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000139',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
#    'peakrssi': -58},
#   {'antenna': 'Antenna1',
#    'datetime': '2022-07-06 18:53:37.0216',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000138',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
# ...

# %%
innermost_1 = instances_1
innermost_2 = instances_2.pop('data')
innermost_3 = instances_3.pop('data')

# %%
innermost_1
# Out:
# [{'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:33.0827',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -56},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:37.0157',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -55},
#  {'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:40.0427',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -58},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:37.0216',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000138',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -59},
# ...

# %%
innermost_2
# Out:
# [{'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:33.0827',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -56},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:37.0157',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -55},
#  {'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:40.0427',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -58},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:37.0216',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000138',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -59},
# ...

# %%
innermost_3
# Out:
# [{'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:33.0827',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -56},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:37.0157',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -55},
#  {'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:40.0427',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -58},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:37.0216',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000138',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -59},
# ...

# %%
inner_1
# Out:
# {'accountuuid': '12345678911223344',
#  'version': '1.0',
#  'deviceid': 'A5:8D:ZC:90:95:9Z',
#  'tenantName': 'GREENVILLE',
#  'eventType': 'EXIT',
#  'eventTimeEpoch': 1657152013}

# %%
files = [innermost_1, innermost_2, innermost_3]

# %%
for file in files:
    print(file)
# Out:
# [{'antenna': 'Antenna2', 'datetime': '2022-07-06 18:53:33.0827', 'readername': 'Modjoul Test 2', 'epc': 'MODJ00000139', 'deviceid': 'A5:8D:ZC:90:95:9Z', 'user': 'null', 'tagevent': 'Tag Visible', 'peakrssi': -56}, {'antenna': 'Antenna1', 'datetime': '2022-07-06 18:53:37.0157', 'readername': 'Modjoul Test 2', 'epc': 'MODJ00000139', 'deviceid': 'A5:8D:ZC:90:95:9Z', 'user': 'null', 'tagevent': 'Tag Visible', 'peakrssi': -55}, {'antenna': 'Antenna2', 'datetime': '2022-07-06 18:53:40.0427', 'readername': 'Modjoul Test 2', 'epc': 'MODJ00000139', 'deviceid': 'A5:8D:ZC:90:95:9Z', 'user': 'null', 'tagevent': 'Tag Visible', 'peakrssi': -58}, {'antenna': 'Antenna1', 'datetime': '2022-07-06 18:53:37.0216', 'readername': 'Modjoul Test 2', 'epc': 'MODJ00000138', 'deviceid': 'A5:8D:ZC:90:95:9Z', 'user': 'null', 'tagevent': 'Tag Visible', 'peakrssi': -59}, {'antenna': 'Antenna1', 'datetime': '2022-07-06 18:53:34.0428', 'readername': 'Modjoul Test 2', 'epc': 'MODJ00000040', 'deviceid': 'A5:8D:ZC:90:9
# ...

# %%
inner_1
# Out:
# {'accountuuid': '12345678911223344',
#  'version': '1.0',
#  'deviceid': 'A5:8D:ZC:90:95:9Z',
#  'tenantName': 'GREENVILLE',
#  'eventType': 'EXIT',
#  'eventTimeEpoch': 1657152013}

# %%
for i in innermost_1:
    i.update(inner_1)

# %%
innermost_1
# Out:
# [{'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:33.0827',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -56,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:37.0157',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -55,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:40.0427',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
# ...

# %%
for i in innermost_2:
    i.update(inner_1)

# %%
innermost_2
# Out:
# [{'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:33.0827',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -56,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:37.0157',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -55,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:40.0427',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
# ...

# %%
for i in innermost_3:
    i.update(inner_1)

# %%
innermost_3
# Out:
# [{'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:33.0827',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -56,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:37.0157',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -55,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:40.0427',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
# ...

# %%
yep = innermost_1 + innermost_2

# %%
yep
# Out:
# [{'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:33.0827',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -56,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:37.0157',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -55,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:40.0427',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
# ...

# %%
final = yep + innermost_3

# %%
final
# Out:
# [{'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:33.0827',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -56,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:37.0157',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -55,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:40.0427',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
# ...

# %%
flat = pd.json_normalize(final, max_level=0)

# %%
flat
# Out:
#      antenna                  datetime      readername           epc  \
# 0   Antenna2  2022-07-06 18:53:33.0827  Modjoul Test 2  MODJ00000139
# 1   Antenna1  2022-07-06 18:53:37.0157  Modjoul Test 2  MODJ00000139
# 2   Antenna2  2022-07-06 18:53:40.0427  Modjoul Test 2  MODJ00000139
# 3   Antenna1  2022-07-06 18:53:37.0216  Modjoul Test 2  MODJ00000138
# 4   Antenna1  2022-07-06 18:53:34.0428  Modjoul Test 2  MODJ00000040
# 5   Antenna1  2022-07-06 18:53:34.0427  Modjoul Test 2  MODJ00000136
# 6   Antenna1  2022-07-06 18:53:38.0717  Modjoul Test 2  MODJ00000136
# 7   Antenna1  2022-07-06 18:53:34.0457  Modjoul Test 2  MODJ00000135
# 8   Antenna1  2022-07-06 18:53:34.0457  Modjoul Test 2  MODJ00000134
# 9   Antenna1  2022-07-06 18:53:34.0607  Modjoul Test 2  MODJ00000133
# 10  Antenna2  2022-07-06 18:53:33.0827  Modjoul Test 2  MODJ00000139
# 11  Antenna1  2022-07-06 18:53:37.0157  Modjoul Test 2  MODJ00000139
# 12  Antenna2  2022-07-06 18:53:40.0427  Modjoul Test 2  MODJ00000139
# ...

# %%
flat.to_csv('final_2.csv')
