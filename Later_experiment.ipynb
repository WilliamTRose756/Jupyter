# %%
import json
import pandas as pd
from pandas import json_normalize

# %%
with open('data_1.json') as data_1:
    read_content_1 = json.load(data_1)
with open('data_2.json') as data_2:
    read_content_2 = json.load(data_2)
with open('data_3.json') as data_3:
    read_content_3 = json.load(data_3)

# %%
read_content_1
# Out:
# [{'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013,
#   'payload': {'data': [{'antenna': 'Antenna2',
#      'datetime': '2022-07-06 18:53:33.0827',
#      'readername': 'Modjoul Test 2',
#      'epc': 'MODJ00000139',
#      'deviceid': 'A5:8D:ZC:90:95:9Z',
#      'user': 'null',
#      'tagevent': 'Tag Visible',
#      'peakrssi': -56},
#     {'antenna': 'Antenna1',
#      'datetime': '2022-07-06 18:53:37.0157',
#      'readername': 'Modjoul Test 2',
#      'epc': 'MODJ00000139',
#      'deviceid': 'A5:8D:ZC:90:95:9Z',
#      'user': 'null',
#      'tagevent': 'Tag Visible',
#      'peakrssi': -55},
#     {'antenna': 'Antenna2',
#      'datetime': '2022-07-06 18:53:40.0427',
#      'readername': 'Modjoul Test 2',
#      'epc': 'MODJ00000139',
#      'deviceid': 'A5:8D:ZC:90:95:9Z',
#      'user': 'null',
#      'tagevent': 'Tag Visible',
#      'peakrssi': -58},
#     {'antenna': 'Antenna1',
#      'datetime': '2022-07-06 18:53:37.0216',
#      'readername': 'Modjoul Test 2',
#      'epc': 'MODJ00000138',
#      'deviceid': 'A5:8D:ZC:90:95:9Z',
#      'user': 'null',
#      'tagevent': 'Tag Visible',
#      'peakrssi': -59},
#     {'antenna': 'Antenna1',
#      'datetime': '2022-07-06 18:53:34.0428',
#      'readername': 'Modjoul Test 2',
#      'epc': 'MODJ00000040',
#      'deviceid': 'A5:8D:ZC:90:95:9Z',
#      'user': 'null',
#      'tagevent': 'Tag Visible',
#      'peakrssi': -61},
#     {'antenna': 'Antenna1',
#      'datetime': '2022-07-06 18:53:34.0427',
#      'readername': 'Modjoul Test 2',
#      'epc': 'MODJ00000136',
#      'deviceid': 'A5:8D:ZC:90:95:9Z',
#      'user': 'null',
#      'tagevent': 'Tag Visible',
#      'peakrssi': -67},
#     {'antenna': 'Antenna1',
#      'datetime': '2022-07-06 18:53:38.0717',
#      'readername': 'Modjoul Test 2',
#      'epc': 'MODJ00000136',
#      'deviceid': 'A5:8D:ZC:90:95:9Z',
#      'user': 'null',
#      'tagevent': 'Tag Visible',
#      'peakrssi': -60},
#     {'antenna': 'Antenna1',
#      'datetime': '2022-07-06 18:53:34.0457',
#      'readername': 'Modjoul Test 2',
#      'epc': 'MODJ00000135',
#      'deviceid': 'A5:8D:ZC:90:95:9Z',
#      'user': 'null',
#      'tagevent': 'Tag Visible',
#      'peakrssi': -68},
#     {'antenna': 'Antenna1',
#      'datetime': '2022-07-06 18:53:34.0457',
#      'readername': 'Modjoul Test 2',
#      'epc': 'MODJ00000134',
#      'deviceid': 'A5:8D:ZC:90:95:9Z',
#      'user': 'null',
#      'tagevent': 'Tag Visible',
#      'peakrssi': -66},
#     {'antenna': 'Antenna1',
#      'datetime': '2022-07-06 18:53:34.0607',
#      'readername': 'Modjoul Test 2',
#      'epc': 'MODJ00000133',
#      'deviceid': 'A5:8D:ZC:90:95:9Z',
#      'user': 'null',
#      'tagevent': 'Tag Visible',
#      'peakrssi': -67}],
#    'accountuuid': '12345678911223344',
#    'version': '1.0',
#    'deviceid': 'A5:8D:ZC:90:95:9Z'}}]

# %%
read_content_1[0]
# Out:
# {'tenantName': 'GREENVILLE',
#  'eventType': 'EXIT',
#  'eventTimeEpoch': 1657152013,
#  'payload': {'data': [{'antenna': 'Antenna2',
#     'datetime': '2022-07-06 18:53:33.0827',
#     'readername': 'Modjoul Test 2',
#     'epc': 'MODJ00000139',
#     'deviceid': 'A5:8D:ZC:90:95:9Z',
#     'user': 'null',
#     'tagevent': 'Tag Visible',
#     'peakrssi': -56},
#    {'antenna': 'Antenna1',
#     'datetime': '2022-07-06 18:53:37.0157',
#     'readername': 'Modjoul Test 2',
#     'epc': 'MODJ00000139',
#     'deviceid': 'A5:8D:ZC:90:95:9Z',
#     'user': 'null',
#     'tagevent': 'Tag Visible',
#     'peakrssi': -55},
#    {'antenna': 'Antenna2',
#     'datetime': '2022-07-06 18:53:40.0427',
#     'readername': 'Modjoul Test 2',
#     'epc': 'MODJ00000139',
#     'deviceid': 'A5:8D:ZC:90:95:9Z',
#     'user': 'null',
#     'tagevent': 'Tag Visible',
#     'peakrssi': -58},
#    {'antenna': 'Antenna1',
#     'datetime': '2022-07-06 18:53:37.0216',
#     'readername': 'Modjoul Test 2',
#     'epc': 'MODJ00000138',
#     'deviceid': 'A5:8D:ZC:90:95:9Z',
#     'user': 'null',
#     'tagevent': 'Tag Visible',
#     'peakrssi': -59},
#    {'antenna': 'Antenna1',
#     'datetime': '2022-07-06 18:53:34.0428',
#     'readername': 'Modjoul Test 2',
#     'epc': 'MODJ00000040',
#     'deviceid': 'A5:8D:ZC:90:95:9Z',
#     'user': 'null',
#     'tagevent': 'Tag Visible',
#     'peakrssi': -61},
#    {'antenna': 'Antenna1',
#     'datetime': '2022-07-06 18:53:34.0427',
#     'readername': 'Modjoul Test 2',
#     'epc': 'MODJ00000136',
#     'deviceid': 'A5:8D:ZC:90:95:9Z',
#     'user': 'null',
#     'tagevent': 'Tag Visible',
#     'peakrssi': -67},
#    {'antenna': 'Antenna1',
#     'datetime': '2022-07-06 18:53:38.0717',
#     'readername': 'Modjoul Test 2',
#     'epc': 'MODJ00000136',
#     'deviceid': 'A5:8D:ZC:90:95:9Z',
#     'user': 'null',
#     'tagevent': 'Tag Visible',
#     'peakrssi': -60},
#    {'antenna': 'Antenna1',
#     'datetime': '2022-07-06 18:53:34.0457',
#     'readername': 'Modjoul Test 2',
#     'epc': 'MODJ00000135',
#     'deviceid': 'A5:8D:ZC:90:95:9Z',
#     'user': 'null',
#     'tagevent': 'Tag Visible',
#     'peakrssi': -68},
#    {'antenna': 'Antenna1',
#     'datetime': '2022-07-06 18:53:34.0457',
#     'readername': 'Modjoul Test 2',
#     'epc': 'MODJ00000134',
#     'deviceid': 'A5:8D:ZC:90:95:9Z',
#     'user': 'null',
#     'tagevent': 'Tag Visible',
#     'peakrssi': -66},
#    {'antenna': 'Antenna1',
#     'datetime': '2022-07-06 18:53:34.0607',
#     'readername': 'Modjoul Test 2',
#     'epc': 'MODJ00000133',
#     'deviceid': 'A5:8D:ZC:90:95:9Z',
#     'user': 'null',
#     'tagevent': 'Tag Visible',
#     'peakrssi': -67}],
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'deviceid': 'A5:8D:ZC:90:95:9Z'}}

# %%
constants =read_content_1[0].pop('payload')
instances_2 =read_content_2[0].pop('payload')
instances_3 =read_content_3[0].pop('payload')

# %%
read_content_1
# Out:
# [{'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013}]

# %%
constants
# Out:
# {'data': [{'antenna': 'Antenna2',
#    'datetime': '2022-07-06 18:53:33.0827',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000139',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
#    'peakrssi': -56},
#   {'antenna': 'Antenna1',
#    'datetime': '2022-07-06 18:53:37.0157',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000139',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
#    'peakrssi': -55},
#   {'antenna': 'Antenna2',
#    'datetime': '2022-07-06 18:53:40.0427',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000139',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
#    'peakrssi': -58},
#   {'antenna': 'Antenna1',
#    'datetime': '2022-07-06 18:53:37.0216',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000138',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
#    'peakrssi': -59},
#   {'antenna': 'Antenna1',
#    'datetime': '2022-07-06 18:53:34.0428',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000040',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
#    'peakrssi': -61},
#   {'antenna': 'Antenna1',
#    'datetime': '2022-07-06 18:53:34.0427',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000136',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
#    'peakrssi': -67},
#   {'antenna': 'Antenna1',
#    'datetime': '2022-07-06 18:53:38.0717',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000136',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
#    'peakrssi': -60},
#   {'antenna': 'Antenna1',
#    'datetime': '2022-07-06 18:53:34.0457',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000135',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
#    'peakrssi': -68},
#   {'antenna': 'Antenna1',
#    'datetime': '2022-07-06 18:53:34.0457',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000134',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
#    'peakrssi': -66},
#   {'antenna': 'Antenna1',
#    'datetime': '2022-07-06 18:53:34.0607',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000133',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
#    'peakrssi': -67}],
#  'accountuuid': '12345678911223344',
#  'version': '1.0',
#  'deviceid': 'A5:8D:ZC:90:95:9Z'}

# %%
# instances_1 = constants.pop('data')

# %%
read_content_1[0]
# Out:
# {'tenantName': 'GREENVILLE', 'eventType': 'EXIT', 'eventTimeEpoch': 1657152013}

# %%
constants.update(read_content_1[0])

# %%
instances_1 = constants.pop('data')

# %%
constants
# Out:
# {'accountuuid': '12345678911223344',
#  'version': '1.0',
#  'deviceid': 'A5:8D:ZC:90:95:9Z',
#  'tenantName': 'GREENVILLE',
#  'eventType': 'EXIT',
#  'eventTimeEpoch': 1657152013}

# %%
instances_1
# Out:
# [{'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:33.0827',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -56},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:37.0157',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -55},
#  {'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:40.0427',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -58},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:37.0216',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000138',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -59},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0428',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000040',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -61},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0427',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000136',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -67},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:38.0717',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000136',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -60},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0457',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000135',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -68},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0457',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000134',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -66},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0607',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000133',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -67}]

# %%
instances_2
# Out:
# {'data': [{'antenna': 'Antenna2',
#    'datetime': '2022-07-06 18:53:33.0827',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000139',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
#    'peakrssi': -56},
#   {'antenna': 'Antenna1',
#    'datetime': '2022-07-06 18:53:37.0157',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000139',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
#    'peakrssi': -55},
#   {'antenna': 'Antenna2',
#    'datetime': '2022-07-06 18:53:40.0427',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000139',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
#    'peakrssi': -58},
#   {'antenna': 'Antenna1',
#    'datetime': '2022-07-06 18:53:37.0216',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000138',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
#    'peakrssi': -59},
#   {'antenna': 'Antenna1',
#    'datetime': '2022-07-06 18:53:34.0428',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000040',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
#    'peakrssi': -61},
#   {'antenna': 'Antenna1',
#    'datetime': '2022-07-06 18:53:34.0427',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000136',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
#    'peakrssi': -67}],
#  'accountuuid': '12345678911223344',
#  'version': '1.0',
#  'deviceid': 'A5:8D:ZC:90:95:9Z'}

# %%
instances_3
# Out:
# {'data': [{'antenna': 'Antenna2',
#    'datetime': '2022-07-06 18:53:33.0827',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000139',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
#    'peakrssi': -56},
#   {'antenna': 'Antenna1',
#    'datetime': '2022-07-06 18:53:37.0157',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000139',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
#    'peakrssi': -55},
#   {'antenna': 'Antenna2',
#    'datetime': '2022-07-06 18:53:40.0427',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000139',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
#    'peakrssi': -58},
#   {'antenna': 'Antenna1',
#    'datetime': '2022-07-06 18:53:37.0216',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000138',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
#    'peakrssi': -59},
#   {'antenna': 'Antenna1',
#    'datetime': '2022-07-06 18:53:34.0428',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000040',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
#    'peakrssi': -61},
#   {'antenna': 'Antenna1',
#    'datetime': '2022-07-06 18:53:34.0427',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000136',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
#    'peakrssi': -67},
#   {'antenna': 'Antenna1',
#    'datetime': '2022-07-06 18:53:38.0717',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000136',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
#    'peakrssi': -60},
#   {'antenna': 'Antenna1',
#    'datetime': '2022-07-06 18:53:34.0457',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000135',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
#    'peakrssi': -68},
#   {'antenna': 'Antenna1',
#    'datetime': '2022-07-06 18:53:34.0457',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000134',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
#    'peakrssi': -66},
#   {'antenna': 'Antenna1',
#    'datetime': '2022-07-06 18:53:34.0607',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000133',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
#    'peakrssi': -67},
#   {'antenna': 'Antenna1',
#    'datetime': '2022-07-06 18:53:34.0457',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000135',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
#    'peakrssi': -68},
#   {'antenna': 'Antenna1',
#    'datetime': '2022-07-06 18:53:34.0457',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000134',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
#    'peakrssi': -66},
#   {'antenna': 'Antenna1',
#    'datetime': '2022-07-06 18:53:34.0607',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000133',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
#    'peakrssi': -67},
#   {'antenna': 'Antenna1',
#    'datetime': '2022-07-06 18:53:34.0457',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000135',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
#    'peakrssi': -68},
#   {'antenna': 'Antenna1',
#    'datetime': '2022-07-06 18:53:34.0457',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000134',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
#    'peakrssi': -66},
#   {'antenna': 'Antenna1',
#    'datetime': '2022-07-06 18:53:34.0607',
#    'readername': 'Modjoul Test 2',
#    'epc': 'MODJ00000133',
#    'deviceid': 'A5:8D:ZC:90:95:9Z',
#    'user': 'null',
#    'tagevent': 'Tag Visible',
#    'peakrssi': -67}],
#  'accountuuid': '12345678911223344',
#  'version': '1.0',
#  'deviceid': 'A5:8D:ZC:90:95:9Z'}

# %%
clean_instances_1 = instances_1
clean_instances_2 = instances_2.pop('data')
clean_instances_3 = instances_3.pop('data')

# %%
clean_instances_1
# Out:
# [{'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:33.0827',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -56},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:37.0157',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -55},
#  {'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:40.0427',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -58},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:37.0216',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000138',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -59},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0428',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000040',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -61},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0427',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000136',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -67},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:38.0717',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000136',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -60},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0457',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000135',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -68},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0457',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000134',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -66},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0607',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000133',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -67}]

# %%
clean_instances_2
# Out:
# [{'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:33.0827',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -56},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:37.0157',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -55},
#  {'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:40.0427',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -58},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:37.0216',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000138',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -59},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0428',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000040',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -61},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0427',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000136',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -67}]

# %%
clean_instances_3
# Out:
# [{'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:33.0827',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -56},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:37.0157',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -55},
#  {'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:40.0427',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -58},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:37.0216',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000138',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -59},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0428',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000040',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -61},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0427',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000136',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -67},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:38.0717',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000136',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -60},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0457',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000135',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -68},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0457',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000134',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -66},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0607',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000133',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -67},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0457',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000135',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -68},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0457',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000134',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -66},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0607',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000133',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -67},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0457',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000135',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -68},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0457',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000134',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -66},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0607',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000133',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -67}]

# %%
constants
# Out:
# {'accountuuid': '12345678911223344',
#  'version': '1.0',
#  'deviceid': 'A5:8D:ZC:90:95:9Z',
#  'tenantName': 'GREENVILLE',
#  'eventType': 'EXIT',
#  'eventTimeEpoch': 1657152013}

# %%
for i in clean_instances_1:
    i.update(constants)

# %%
clean_instances_1
# Out:
# [{'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:33.0827',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -56,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:37.0157',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -55,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:40.0427',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -58,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:37.0216',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000138',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -59,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0428',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000040',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -61,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0427',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000136',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -67,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:38.0717',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000136',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -60,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0457',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000135',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -68,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0457',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000134',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -66,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0607',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000133',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -67,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013}]

# %%
for i in clean_instances_2:
    i.update(constants)

# %%
clean_instances_2
# Out:
# [{'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:33.0827',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -56,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:37.0157',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -55,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:40.0427',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -58,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:37.0216',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000138',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -59,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0428',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000040',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -61,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0427',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000136',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -67,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013}]

# %%
for i in clean_instances_3:
    i.update(constants)

# %%
clean_instances_3
# Out:
# [{'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:33.0827',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -56,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:37.0157',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -55,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:40.0427',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -58,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:37.0216',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000138',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -59,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0428',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000040',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -61,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0427',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000136',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -67,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:38.0717',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000136',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -60,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0457',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000135',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -68,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0457',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000134',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -66,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0607',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000133',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -67,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0457',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000135',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -68,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0457',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000134',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -66,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0607',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000133',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -67,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0457',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000135',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -68,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0457',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000134',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -66,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0607',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000133',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -67,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013}]

# %%
grouped = clean_instances_1 + clean_instances_2 + clean_instances_3

# %%
grouped
# Out:
# [{'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:33.0827',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -56,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:37.0157',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -55,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:40.0427',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -58,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:37.0216',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000138',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -59,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0428',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000040',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -61,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0427',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000136',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -67,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:38.0717',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000136',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -60,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0457',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000135',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -68,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0457',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000134',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -66,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0607',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000133',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -67,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:33.0827',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -56,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:37.0157',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -55,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:40.0427',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -58,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:37.0216',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000138',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -59,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0428',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000040',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -61,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0427',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000136',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -67,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:33.0827',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -56,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:37.0157',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -55,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna2',
#   'datetime': '2022-07-06 18:53:40.0427',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000139',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -58,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:37.0216',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000138',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -59,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0428',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000040',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -61,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0427',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000136',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -67,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:38.0717',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000136',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -60,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0457',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000135',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -68,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0457',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000134',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -66,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0607',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000133',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -67,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0457',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000135',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -68,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0457',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000134',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -66,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0607',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000133',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -67,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0457',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000135',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -68,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0457',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000134',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -66,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013},
#  {'antenna': 'Antenna1',
#   'datetime': '2022-07-06 18:53:34.0607',
#   'readername': 'Modjoul Test 2',
#   'epc': 'MODJ00000133',
#   'deviceid': 'A5:8D:ZC:90:95:9Z',
#   'user': 'null',
#   'tagevent': 'Tag Visible',
#   'peakrssi': -67,
#   'accountuuid': '12345678911223344',
#   'version': '1.0',
#   'tenantName': 'GREENVILLE',
#   'eventType': 'EXIT',
#   'eventTimeEpoch': 1657152013}]

# %%
flat = pd.json_normalize(grouped, max_level=0)

# %%
flat
# Out:
#      antenna                  datetime      readername           epc  \
# 0   Antenna2  2022-07-06 18:53:33.0827  Modjoul Test 2  MODJ00000139
# 1   Antenna1  2022-07-06 18:53:37.0157  Modjoul Test 2  MODJ00000139
# 2   Antenna2  2022-07-06 18:53:40.0427  Modjoul Test 2  MODJ00000139
# 3   Antenna1  2022-07-06 18:53:37.0216  Modjoul Test 2  MODJ00000138
# 4   Antenna1  2022-07-06 18:53:34.0428  Modjoul Test 2  MODJ00000040
# 5   Antenna1  2022-07-06 18:53:34.0427  Modjoul Test 2  MODJ00000136
# 6   Antenna1  2022-07-06 18:53:38.0717  Modjoul Test 2  MODJ00000136
# 7   Antenna1  2022-07-06 18:53:34.0457  Modjoul Test 2  MODJ00000135
# 8   Antenna1  2022-07-06 18:53:34.0457  Modjoul Test 2  MODJ00000134
# 9   Antenna1  2022-07-06 18:53:34.0607  Modjoul Test 2  MODJ00000133
# 10  Antenna2  2022-07-06 18:53:33.0827  Modjoul Test 2  MODJ00000139
# 11  Antenna1  2022-07-06 18:53:37.0157  Modjoul Test 2  MODJ00000139
# 12  Antenna2  2022-07-06 18:53:40.0427  Modjoul Test 2  MODJ00000139
# 13  Antenna1  2022-07-06 18:53:37.0216  Modjoul Test 2  MODJ00000138
# 14  Antenna1  2022-07-06 18:53:34.0428  Modjoul Test 2  MODJ00000040
# 15  Antenna1  2022-07-06 18:53:34.0427  Modjoul Test 2  MODJ00000136
# 16  Antenna2  2022-07-06 18:53:33.0827  Modjoul Test 2  MODJ00000139
# 17  Antenna1  2022-07-06 18:53:37.0157  Modjoul Test 2  MODJ00000139
# 18  Antenna2  2022-07-06 18:53:40.0427  Modjoul Test 2  MODJ00000139
# 19  Antenna1  2022-07-06 18:53:37.0216  Modjoul Test 2  MODJ00000138
# 20  Antenna1  2022-07-06 18:53:34.0428  Modjoul Test 2  MODJ00000040
# 21  Antenna1  2022-07-06 18:53:34.0427  Modjoul Test 2  MODJ00000136
# 22  Antenna1  2022-07-06 18:53:38.0717  Modjoul Test 2  MODJ00000136
# 23  Antenna1  2022-07-06 18:53:34.0457  Modjoul Test 2  MODJ00000135
# 24  Antenna1  2022-07-06 18:53:34.0457  Modjoul Test 2  MODJ00000134
# 25  Antenna1  2022-07-06 18:53:34.0607  Modjoul Test 2  MODJ00000133
# 26  Antenna1  2022-07-06 18:53:34.0457  Modjoul Test 2  MODJ00000135
# 27  Antenna1  2022-07-06 18:53:34.0457  Modjoul Test 2  MODJ00000134
# 28  Antenna1  2022-07-06 18:53:34.0607  Modjoul Test 2  MODJ00000133
# 29  Antenna1  2022-07-06 18:53:34.0457  Modjoul Test 2  MODJ00000135
# 30  Antenna1  2022-07-06 18:53:34.0457  Modjoul Test 2  MODJ00000134
# 31  Antenna1  2022-07-06 18:53:34.0607  Modjoul Test 2  MODJ00000133
#
#              deviceid  user     tagevent  peakrssi        accountuuid version  \
# 0   A5:8D:ZC:90:95:9Z  null  Tag Visible       -56  12345678911223344     1.0
# 1   A5:8D:ZC:90:95:9Z  null  Tag Visible       -55  12345678911223344     1.0
# 2   A5:8D:ZC:90:95:9Z  null  Tag Visible       -58  12345678911223344     1.0
# 3   A5:8D:ZC:90:95:9Z  null  Tag Visible       -59  12345678911223344     1.0
# 4   A5:8D:ZC:90:95:9Z  null  Tag Visible       -61  12345678911223344     1.0
# 5   A5:8D:ZC:90:95:9Z  null  Tag Visible       -67  12345678911223344     1.0
# 6   A5:8D:ZC:90:95:9Z  null  Tag Visible       -60  12345678911223344     1.0
# 7   A5:8D:ZC:90:95:9Z  null  Tag Visible       -68  12345678911223344     1.0
# 8   A5:8D:ZC:90:95:9Z  null  Tag Visible       -66  12345678911223344     1.0
# 9   A5:8D:ZC:90:95:9Z  null  Tag Visible       -67  12345678911223344     1.0
# 10  A5:8D:ZC:90:95:9Z  null  Tag Visible       -56  12345678911223344     1.0
# 11  A5:8D:ZC:90:95:9Z  null  Tag Visible       -55  12345678911223344     1.0
# 12  A5:8D:ZC:90:95:9Z  null  Tag Visible       -58  12345678911223344     1.0
# 13  A5:8D:ZC:90:95:9Z  null  Tag Visible       -59  12345678911223344     1.0
# 14  A5:8D:ZC:90:95:9Z  null  Tag Visible       -61  12345678911223344     1.0
# 15  A5:8D:ZC:90:95:9Z  null  Tag Visible       -67  12345678911223344     1.0
# 16  A5:8D:ZC:90:95:9Z  null  Tag Visible       -56  12345678911223344     1.0
# 17  A5:8D:ZC:90:95:9Z  null  Tag Visible       -55  12345678911223344     1.0
# 18  A5:8D:ZC:90:95:9Z  null  Tag Visible       -58  12345678911223344     1.0
# 19  A5:8D:ZC:90:95:9Z  null  Tag Visible       -59  12345678911223344     1.0
# 20  A5:8D:ZC:90:95:9Z  null  Tag Visible       -61  12345678911223344     1.0
# 21  A5:8D:ZC:90:95:9Z  null  Tag Visible       -67  12345678911223344     1.0
# 22  A5:8D:ZC:90:95:9Z  null  Tag Visible       -60  12345678911223344     1.0
# 23  A5:8D:ZC:90:95:9Z  null  Tag Visible       -68  12345678911223344     1.0
# 24  A5:8D:ZC:90:95:9Z  null  Tag Visible       -66  12345678911223344     1.0
# 25  A5:8D:ZC:90:95:9Z  null  Tag Visible       -67  12345678911223344     1.0
# 26  A5:8D:ZC:90:95:9Z  null  Tag Visible       -68  12345678911223344     1.0
# 27  A5:8D:ZC:90:95:9Z  null  Tag Visible       -66  12345678911223344     1.0
# 28  A5:8D:ZC:90:95:9Z  null  Tag Visible       -67  12345678911223344     1.0
# 29  A5:8D:ZC:90:95:9Z  null  Tag Visible       -68  12345678911223344     1.0
# 30  A5:8D:ZC:90:95:9Z  null  Tag Visible       -66  12345678911223344     1.0
# 31  A5:8D:ZC:90:95:9Z  null  Tag Visible       -67  12345678911223344     1.0
#
#     tenantName eventType  eventTimeEpoch
# 0   GREENVILLE      EXIT      1657152013
# 1   GREENVILLE      EXIT      1657152013
# 2   GREENVILLE      EXIT      1657152013
# 3   GREENVILLE      EXIT      1657152013
# 4   GREENVILLE      EXIT      1657152013
# 5   GREENVILLE      EXIT      1657152013
# 6   GREENVILLE      EXIT      1657152013
# 7   GREENVILLE      EXIT      1657152013
# 8   GREENVILLE      EXIT      1657152013
# 9   GREENVILLE      EXIT      1657152013
# 10  GREENVILLE      EXIT      1657152013
# 11  GREENVILLE      EXIT      1657152013
# 12  GREENVILLE      EXIT      1657152013
# 13  GREENVILLE      EXIT      1657152013
# 14  GREENVILLE      EXIT      1657152013
# 15  GREENVILLE      EXIT      1657152013
# 16  GREENVILLE      EXIT      1657152013
# 17  GREENVILLE      EXIT      1657152013
# 18  GREENVILLE      EXIT      1657152013
# 19  GREENVILLE      EXIT      1657152013
# 20  GREENVILLE      EXIT      1657152013
# 21  GREENVILLE      EXIT      1657152013
# 22  GREENVILLE      EXIT      1657152013
# 23  GREENVILLE      EXIT      1657152013
# 24  GREENVILLE      EXIT      1657152013
# 25  GREENVILLE      EXIT      1657152013
# 26  GREENVILLE      EXIT      1657152013
# 27  GREENVILLE      EXIT      1657152013
# 28  GREENVILLE      EXIT      1657152013
# 29  GREENVILLE      EXIT      1657152013
# 30  GREENVILLE      EXIT      1657152013
# 31  GREENVILLE      EXIT      1657152013

# %%
final = flat[['tenantName', 'eventType', 'eventTimeEpoch', 'antenna', 'datetime', 'readername', 'epc', 'deviceid', 'user', 'tagevent', 'peakrssi', 'accountuuid', 'version']]

# %%
final
# Out:
#     tenantName eventType  eventTimeEpoch   antenna                  datetime  \
# 0   GREENVILLE      EXIT      1657152013  Antenna2  2022-07-06 18:53:33.0827
# 1   GREENVILLE      EXIT      1657152013  Antenna1  2022-07-06 18:53:37.0157
# 2   GREENVILLE      EXIT      1657152013  Antenna2  2022-07-06 18:53:40.0427
# 3   GREENVILLE      EXIT      1657152013  Antenna1  2022-07-06 18:53:37.0216
# 4   GREENVILLE      EXIT      1657152013  Antenna1  2022-07-06 18:53:34.0428
# 5   GREENVILLE      EXIT      1657152013  Antenna1  2022-07-06 18:53:34.0427
# 6   GREENVILLE      EXIT      1657152013  Antenna1  2022-07-06 18:53:38.0717
# 7   GREENVILLE      EXIT      1657152013  Antenna1  2022-07-06 18:53:34.0457
# 8   GREENVILLE      EXIT      1657152013  Antenna1  2022-07-06 18:53:34.0457
# 9   GREENVILLE      EXIT      1657152013  Antenna1  2022-07-06 18:53:34.0607
# 10  GREENVILLE      EXIT      1657152013  Antenna2  2022-07-06 18:53:33.0827
# 11  GREENVILLE      EXIT      1657152013  Antenna1  2022-07-06 18:53:37.0157
# 12  GREENVILLE      EXIT      1657152013  Antenna2  2022-07-06 18:53:40.0427
# 13  GREENVILLE      EXIT      1657152013  Antenna1  2022-07-06 18:53:37.0216
# 14  GREENVILLE      EXIT      1657152013  Antenna1  2022-07-06 18:53:34.0428
# 15  GREENVILLE      EXIT      1657152013  Antenna1  2022-07-06 18:53:34.0427
# 16  GREENVILLE      EXIT      1657152013  Antenna2  2022-07-06 18:53:33.0827
# 17  GREENVILLE      EXIT      1657152013  Antenna1  2022-07-06 18:53:37.0157
# 18  GREENVILLE      EXIT      1657152013  Antenna2  2022-07-06 18:53:40.0427
# 19  GREENVILLE      EXIT      1657152013  Antenna1  2022-07-06 18:53:37.0216
# 20  GREENVILLE      EXIT      1657152013  Antenna1  2022-07-06 18:53:34.0428
# 21  GREENVILLE      EXIT      1657152013  Antenna1  2022-07-06 18:53:34.0427
# 22  GREENVILLE      EXIT      1657152013  Antenna1  2022-07-06 18:53:38.0717
# 23  GREENVILLE      EXIT      1657152013  Antenna1  2022-07-06 18:53:34.0457
# 24  GREENVILLE      EXIT      1657152013  Antenna1  2022-07-06 18:53:34.0457
# 25  GREENVILLE      EXIT      1657152013  Antenna1  2022-07-06 18:53:34.0607
# 26  GREENVILLE      EXIT      1657152013  Antenna1  2022-07-06 18:53:34.0457
# 27  GREENVILLE      EXIT      1657152013  Antenna1  2022-07-06 18:53:34.0457
# 28  GREENVILLE      EXIT      1657152013  Antenna1  2022-07-06 18:53:34.0607
# 29  GREENVILLE      EXIT      1657152013  Antenna1  2022-07-06 18:53:34.0457
# 30  GREENVILLE      EXIT      1657152013  Antenna1  2022-07-06 18:53:34.0457
# 31  GREENVILLE      EXIT      1657152013  Antenna1  2022-07-06 18:53:34.0607
#
#         readername           epc           deviceid  user     tagevent  \
# 0   Modjoul Test 2  MODJ00000139  A5:8D:ZC:90:95:9Z  null  Tag Visible
# 1   Modjoul Test 2  MODJ00000139  A5:8D:ZC:90:95:9Z  null  Tag Visible
# 2   Modjoul Test 2  MODJ00000139  A5:8D:ZC:90:95:9Z  null  Tag Visible
# 3   Modjoul Test 2  MODJ00000138  A5:8D:ZC:90:95:9Z  null  Tag Visible
# 4   Modjoul Test 2  MODJ00000040  A5:8D:ZC:90:95:9Z  null  Tag Visible
# 5   Modjoul Test 2  MODJ00000136  A5:8D:ZC:90:95:9Z  null  Tag Visible
# 6   Modjoul Test 2  MODJ00000136  A5:8D:ZC:90:95:9Z  null  Tag Visible
# 7   Modjoul Test 2  MODJ00000135  A5:8D:ZC:90:95:9Z  null  Tag Visible
# 8   Modjoul Test 2  MODJ00000134  A5:8D:ZC:90:95:9Z  null  Tag Visible
# 9   Modjoul Test 2  MODJ00000133  A5:8D:ZC:90:95:9Z  null  Tag Visible
# 10  Modjoul Test 2  MODJ00000139  A5:8D:ZC:90:95:9Z  null  Tag Visible
# 11  Modjoul Test 2  MODJ00000139  A5:8D:ZC:90:95:9Z  null  Tag Visible
# 12  Modjoul Test 2  MODJ00000139  A5:8D:ZC:90:95:9Z  null  Tag Visible
# 13  Modjoul Test 2  MODJ00000138  A5:8D:ZC:90:95:9Z  null  Tag Visible
# 14  Modjoul Test 2  MODJ00000040  A5:8D:ZC:90:95:9Z  null  Tag Visible
# 15  Modjoul Test 2  MODJ00000136  A5:8D:ZC:90:95:9Z  null  Tag Visible
# 16  Modjoul Test 2  MODJ00000139  A5:8D:ZC:90:95:9Z  null  Tag Visible
# 17  Modjoul Test 2  MODJ00000139  A5:8D:ZC:90:95:9Z  null  Tag Visible
# 18  Modjoul Test 2  MODJ00000139  A5:8D:ZC:90:95:9Z  null  Tag Visible
# 19  Modjoul Test 2  MODJ00000138  A5:8D:ZC:90:95:9Z  null  Tag Visible
# 20  Modjoul Test 2  MODJ00000040  A5:8D:ZC:90:95:9Z  null  Tag Visible
# 21  Modjoul Test 2  MODJ00000136  A5:8D:ZC:90:95:9Z  null  Tag Visible
# 22  Modjoul Test 2  MODJ00000136  A5:8D:ZC:90:95:9Z  null  Tag Visible
# 23  Modjoul Test 2  MODJ00000135  A5:8D:ZC:90:95:9Z  null  Tag Visible
# 24  Modjoul Test 2  MODJ00000134  A5:8D:ZC:90:95:9Z  null  Tag Visible
# 25  Modjoul Test 2  MODJ00000133  A5:8D:ZC:90:95:9Z  null  Tag Visible
# 26  Modjoul Test 2  MODJ00000135  A5:8D:ZC:90:95:9Z  null  Tag Visible
# 27  Modjoul Test 2  MODJ00000134  A5:8D:ZC:90:95:9Z  null  Tag Visible
# 28  Modjoul Test 2  MODJ00000133  A5:8D:ZC:90:95:9Z  null  Tag Visible
# 29  Modjoul Test 2  MODJ00000135  A5:8D:ZC:90:95:9Z  null  Tag Visible
# 30  Modjoul Test 2  MODJ00000134  A5:8D:ZC:90:95:9Z  null  Tag Visible
# 31  Modjoul Test 2  MODJ00000133  A5:8D:ZC:90:95:9Z  null  Tag Visible
#
#     peakrssi        accountuuid version
# 0        -56  12345678911223344     1.0
# 1        -55  12345678911223344     1.0
# 2        -58  12345678911223344     1.0
# 3        -59  12345678911223344     1.0
# 4        -61  12345678911223344     1.0
# 5        -67  12345678911223344     1.0
# 6        -60  12345678911223344     1.0
# 7        -68  12345678911223344     1.0
# 8        -66  12345678911223344     1.0
# 9        -67  12345678911223344     1.0
# 10       -56  12345678911223344     1.0
# 11       -55  12345678911223344     1.0
# 12       -58  12345678911223344     1.0
# 13       -59  12345678911223344     1.0
# 14       -61  12345678911223344     1.0
# 15       -67  12345678911223344     1.0
# 16       -56  12345678911223344     1.0
# 17       -55  12345678911223344     1.0
# 18       -58  12345678911223344     1.0
# 19       -59  12345678911223344     1.0
# 20       -61  12345678911223344     1.0
# 21       -67  12345678911223344     1.0
# 22       -60  12345678911223344     1.0
# 23       -68  12345678911223344     1.0
# 24       -66  12345678911223344     1.0
# 25       -67  12345678911223344     1.0
# 26       -68  12345678911223344     1.0
# 27       -66  12345678911223344     1.0
# 28       -67  12345678911223344     1.0
# 29       -68  12345678911223344     1.0
# 30       -66  12345678911223344     1.0
# 31       -67  12345678911223344     1.0

# %%
final.to_csv('final_3.csv', index=None)
